# %% [markdown]
# <a href="https://colab.research.google.com/github/CD-AC/Master_AI/blob/main/RegresionLinealMultiple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regresión Lineal Multiple

# %% [markdown]
# ![RLM.png](data:image/png;base64,...)

# %% [markdown]
# ## Restricciones Regresión Lineal Multiple
# 1. Linealidad: Se asume que la relación entre las variables independientes y la variable dependiente puede describirse de forma lineal. Esto significa que un cambio en la variable independiente produce un efecto constante en la variable dependiente.
#
# 2. Homocedasticidad: Implica que la varianza de los errores (o residuos) es constante a lo largo de todos los valores de las variables independientes. En otras palabras, se espera que la dispersión de los errores sea la misma sin importar el nivel de las variables predictoras.
#
# 3. Normalidad multivariable: Se requiere que los errores de la regresión (o, en un contexto más amplio, los valores de las variables) sigan una distribución normal. Esto ayuda a que los intervalos de confianza y las pruebas de hipótesis sean válidas.
#
# 4. Independencia de los errores: Establece que los errores no deben estar correlacionados entre sí. Por ejemplo, en datos de series temporales, los errores de un período no deberían influir en los errores de otros períodos.
#
# 5. Ausencia de multicolinealidad: Significa que las variables independientes no deben estar fuertemente correlacionadas entre sí. Una alta correlación entre variables independientes puede distorsionar las estimaciones de los coeficientes y dificultar la interpretación del modelo.

# %% [markdown]
# ## p-valor
# Es la probabilidad, suponiendo que la hipótesis nula sea verdadera, de obtener un resultado tan extremo (o más extremo) que el observado en tu muestra de datos. En otras palabras, mide la evidencia en contra de la hipótesis nula: mientras más pequeño sea el p-valor, más evidencia hay para rechazar dicha hipótesis. Si el p-valor es menor que un nivel de significancia establecido (por ejemplo, 0.05), normalmente se concluye que existe suficiente evidencia estadística para descartar la hipótesis nula.

# %% [markdown]
# # Importar Dependencias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %% [markdown]
# # Importar Dataset

# %%
df = pd.read_csv('/content/50_Startups.csv')
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# # Codificación de Datos Categoricos

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, 4].values

# %%
X.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-ae5cd47bda90> in <cell line: 1>()
# ----> 1 X.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
LabelEncoder_X = LabelEncoder()
X[:, 3] = LabelEncoder_X.fit_transform(X[:, 3])
OneHotEncoder = OneHotEncoder(categorical_features=[3])
X = OneHotEncoder.fit_transform(X).toarray()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-90c938fdc11a> in <cell line: 3>()
#       1 LabelEncoder_X = LabelEncoder()
#       2 X[:, 3] = LabelEncoder_X.fit_transform(X[:, 3])
# ----> 3 OneHotEncoder = OneHotEncoder(categorical_features=[3])
#       4 X = OneHotEncoder.fit_transform(X).toarray()
#
# TypeError: OneHotEncoder.__init__() got an unexpected keyword argument 'categorical_features'
